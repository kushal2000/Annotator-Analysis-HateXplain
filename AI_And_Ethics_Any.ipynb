# %% [markdown]
# ## Create Dataset ##

# %%
import pandas as pd
import csv
import numpy as np

# %%
data = pd.read_csv("train_file.csv")
data["target_processed"] = data.target.apply(lambda y: y.lstrip('[').rstrip(']').replace("'","").replace(", ",",").split(","))

# %%
data_train
# Out:
#        label  annotator_id  ... targetNonreligious  targetAsian
# 0          2           204  ...                  0            0
# 1          2           209  ...                  0            0
# 2          2           222  ...                  0            0
# 3          1           202  ...                  0            0
# 4          2           221  ...                  0            0
# ...      ...           ...  ...                ...          ...
# 11548      2           217  ...                  0            1
# 11549      1           209  ...                  0            0
# 11550      1           127  ...                  0            0
# 11551      1            18  ...                  0            0
# 11552      0             1  ...                  0            0
#
# [11553 rows x 66 columns]

# %%
def convert_list(x, target, name = "target"):
    diction = {}
    for y in target:
        if y in x:
            diction[name + y] = diction.get(y,1)
        else:
            diction[name + y] = 0
    return diction

# %%
def one_hot_data(file_name):
    data = pd.read_csv(file_name)
    data["text_processed"] = data.text.apply(lambda y: " ".join(y.lstrip('[').rstrip(']').replace("'","").replace(", ",",").split(",")))
    data["target_processed"] = data.target.apply(lambda y: y.lstrip('[').rstrip(']').replace("'","").replace(", ",",").split(","))
    data = data.drop(columns=['target','text'])
    data.Country = data.Country.str.replace("{}","NA_Country")
    data = pd.concat([data.drop(columns= ["Country"]), pd.get_dummies(data['Country'])], axis=1)
    data = pd.concat([data.drop(columns= ["Race"]), pd.get_dummies(data['Race'])], axis=1)
    data.Religion = data.Religion.str.replace("Other","Other_Rel")
    data = pd.concat([data.drop(columns= ["Religion"]), pd.get_dummies(data['Religion'])], axis=1)
    data.Gender = data.Gender.str.replace("Prefer not to disclose","NoMentionGender")
    data = pd.concat([data.drop(columns= ["Gender"]), pd.get_dummies(data['Gender'])], axis=1)
    data = pd.concat([data.drop(columns= ["Age"]), pd.get_dummies(data['Age'])], axis=1)
    all_targets = list(data.target_processed)
    targets = [x for y in all_targets for x in y ]
    targets = list(set(targets))
    A = data.target_processed.apply(lambda x: convert_list(x,targets))
    A = A.apply(pd.Series)
    data = pd.concat([data.drop(columns= ["target_processed"]), A], axis=1)
    return data

# %%
data_train = one_hot_data('train_file.csv')

# %%
data_valid = one_hot_data('valid_file.csv')

# %%
data_test = one_hot_data('test_file.csv')

# %%
x1 = data_train.keys()

# %%
data_train = data_train.reindex(columns=x1, fill_value= 0)

# %%
data_test = data_test.reindex(columns=x1, fill_value= 0)

# %%
data_valid = data_valid.reindex(columns=x1, fill_value= 0)

# %%
data_train.to_csv('one_hot_train.csv')

# %%
data_valid.to_csv('one_hot_valid.csv')

# %%
data_test.to_csv('one_hot_test.csv')

# %%
x2 = data_valid.keys()

# %%
x3 = data_test.keys()

# %%
df = data_train[x1]

# %%
df.reindex(columns=x1)
# Out:
#        label  annotator_id  ... targetNonreligious  targetAsian
# 0          2           204  ...                  0            0
# 1          2           209  ...                  0            0
# 2          2           222  ...                  0            0
# 3          1           202  ...                  0            0
# 4          2           221  ...                  0            0
# ...      ...           ...  ...                ...          ...
# 11548      2           217  ...                  0            1
# 11549      1           209  ...                  0            0
# 11550      1           127  ...                  0            0
# 11551      1            18  ...                  0            0
# 11552      0             1  ...                  0            0
#
# [11553 rows x 66 columns]

# %%
data_valid.reindex(columns = x1)
# Out:
#       label  annotator_id  ... targetNonreligious  targetAsian
# 0         1             3  ...                  0            0
# 1         1             9  ...                  0            0
# 2         1           215  ...                  0            0
# 3         1           207  ...                  0            0
# 4         1            84  ...                  0            0
# ...     ...           ...  ...                ...          ...
# 1414      2           216  ...                  0            0
# 1415      2           204  ...                  0            0
# 1416      0           199  ...                  0            0
# 1417      0            23  ...                  0            0
# 1418      0             3  ...                  0            0
#
# [1419 rows x 66 columns]

# %%
len(x2)
# Out:
# 58

# %%
len(x3)
# Out:
# 59

# %%
for i in x1:
    if i not in x2:
        print(i)
# Out:
# Botswana
# Israel
# UK
# United Arab Emirates
# United Kingdom
# Vietnam
# targetBisexual
# targetEconomic

# %%
for i in x1:
    if i not in x3:
        print(i)
# Out:
# Botswana
# Israel
# United Arab Emirates
# United Kingdom
# targetBisexual
# targetEconomic
# targetHindu
# targetBuddhism
# targetIndian

# %%
data = pd.read_csv("annotators_race.csv")

# %%
data["text_processed"] = data.text.apply(lambda y: " ".join(y.lstrip('[').rstrip(']').replace("'","").replace(", ",",").split(",")))

# %%
# data

# %%
data["target_processed"] = data.target.apply(lambda y: y.lstrip('[').rstrip(']').replace("'","").replace(", ",",").split(","))

# %%
data = data.drop(columns=['target','text'])

# %%
data.Country = data.Country.str.replace("{}","NA_Country")

# %%
data.Country.unique()
# Out:
# array(['USA', 'Canada', 'India', 'Brazil', 'Italy', 'Spain', 'Turkey',
#        'United Arab Emirates', 'Germany', 'France', 'Botswana', 'UK',
#        'Vietnam', 'NA_Country', 'Mexico', 'United Kingdom'], dtype=object)

# %%
data = pd.concat([data.drop(columns= ["Country"]), pd.get_dummies(data['Country'])], axis=1)

# %%
data.Race.unique()
# Out:
# array(['Hispanic', 'Caucasian', 'Indian', 'African', 'Other', 'Arabs',
#        'Asians'], dtype=object)

# %%
data = pd.concat([data.drop(columns= ["Race"]), pd.get_dummies(data['Race'])], axis=1)

# %%
data.Religion.unique()
# Out:
# array(['Other', 'Nonreligious', 'Hindu', 'Christian', 'Islam', 'Jews'],
#       dtype=object)

# %%
data.Religion = data.Religion.str.replace("Other","Other_Rel")

# %%
data = pd.concat([data.drop(columns= ["Religion"]), pd.get_dummies(data['Religion'])], axis=1)

# %%
data.Gender = data.Gender.str.replace("Prefer not to disclose","NoMentionGender")

# %%
data.Gender.unique()
# Out:
# array(['Female', 'Male', 'NoMentionGender'], dtype=object)

# %%
data = pd.concat([data.drop(columns= ["Gender"]), pd.get_dummies(data['Gender'])], axis=1)

# %%
all_targets = list(data.target_processed)

# %%
targets = [x for y in all_targets for x in y ]

# %%
targets = list(set(targets))

# %%
 A = data.target_processed.apply(lambda x: convert_list(x,targets))

# %%
A
# Out:
# 0        {'targetWomen': 0, 'targetIslam': 1, 'targetMe...
# 1        {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# 2        {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# 3        {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# 4        {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
#                                ...
# 14237    {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# 14238    {'targetWomen': 0, 'targetIslam': 1, 'targetMe...
# 14239    {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# 14240    {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# 14241    {'targetWomen': 0, 'targetIslam': 0, 'targetMe...
# Name: target_processed, Length: 14242, dtype: object

# %%
A = A.apply(pd.Series)

# %%
data = pd.concat([data.drop(columns= ["target_processed"]), A], axis=1)

# %%
data
# Out:
#        label  annotator_id  ... targetIndian  targetArab
# 0          2           204  ...            0           0
# 1          2           222  ...            0           0
# 2          2           209  ...            0           0
# 3          2            25  ...            0           0
# 4          1           202  ...            0           0
# ...      ...           ...  ...          ...         ...
# 14237      2           206  ...            0           0
# 14238      1           209  ...            0           0
# 14239      1            37  ...            0           0
# 14240      1            18  ...            0           0
# 14241      0             9  ...            0           0
#
# [14242 rows x 60 columns]

# %%
data.to_csv("One_hot.csv")

# %%
df = data[["label","text_processed","Race"]]

# %%
train_dev = df[df.Race =="Caucasian"]

# %%
test = df[df.Race!="Caucasian"]

# %%
temp_df = df.copy()

# %% [markdown]
# ## Actual Code ##

# %%
# !pip install transformers

# %%
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, BertConfig, get_linear_schedule_with_warmup
import numpy as np
import torch
import torch.nn as nn
import time
import datetime
import random
import os
import os.path
from sklearn import metrics

# %%
from transformers import BertModel

# %%
train = pd.read_csv('one_hot_train.csv')
cols = train.columns

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class NewModel(nn.Module):
    def __init__(self, model_bert, input_dim = 63, output_dim = 3, device = torch.device('cuda')):
        super(NewModel, self).__init__()
        self.model_bert = model_bert
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.device = device
        self.fc1 = nn.Linear(768+input_dim, output_dim)
    def forward(self,x):
        ids = x[0].to(self.device)
        masks = x[1].to(self.device)
        demos = x[2].to(self.device)
        sent_emb = self.model_bert(ids, token_type_ids = None, attention_mask = masks)
        sent_logits = sent_emb[1]
        new_emb = torch.cat((sent_logits,demos),1)
        out_logits = self.fc1(new_emb)
        return out_logits

# %%
def evaluate(y_true, y_pred):
  
    assert len(y_true) == len(y_pred)
    precision, recall, f1, _ = metrics.precision_recall_fscore_support(y_true, y_pred, labels=[0, 1, 2], average='macro')
    acc = np.mean(y_true == y_pred)
    scores = [
        "F1: %f\n" % f1,
        "Recall: %f\n" % recall,
        "Precision: %f\n" % precision,
        "Acc: %f\n" % acc
    ]
    # for s in scores:
    #     print(s, end='')
    return f1, acc

# %%
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)
    
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def test_stats(test, tokenizer, model, MAX_LEN):
    if len(test)==0:
        return None
    test_sentences = test.text_processed.values
    test_demos = test[cols[4:]].values
    test_labels = test.label.values
    test_input_ids = []
    MAX_LEN = 128*2
    for sent in test_sentences:
        encoded_sent = tokenizer.encode(str(sent),add_special_tokens = True,)
        test_input_ids.append(encoded_sent)
    test_input_ids = pad_sequences(test_input_ids, maxlen=MAX_LEN, 
                            dtype="long", truncating="post", padding="post")
    test_attention_masks = []
    for seq in test_input_ids:
        seq_mask = [float(i>0) for i in seq]
        test_attention_masks.append(seq_mask) 
    prediction_inputs = torch.tensor(test_input_ids).to(torch.int64)
    prediction_masks = torch.tensor(test_attention_masks)
    prediction_labels = torch.tensor(test_labels).to(torch.int64)
    prediction_demos = torch.tensor(test_demos).to(torch.int64)
    batch_size = 8  
    prediction_data = TensorDataset(prediction_inputs, prediction_masks, prediction_demos, prediction_labels)
    prediction_sampler = SequentialSampler(prediction_data)
    prediction_dataloader = DataLoader(prediction_data, sampler=prediction_sampler, batch_size=batch_size)
    # print('Predicting labels for {:,} test sentences...'.format(len(prediction_inputs)))
    model.eval()
    predictions , true_labels = [], []
    for batch in prediction_dataloader:
        batch = tuple(t.to(device) for t in batch)
    
        with torch.no_grad():
            outputs = model(batch)

        logits = outputs
        b_labels = batch[-1]
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        predictions.append(logits)
        true_labels.append(label_ids)

    # print('    DONE.')
    
    flat_predictions = [item for sublist in predictions for item in sublist]
    flat_predictions = np.argmax(flat_predictions, axis=1).flatten()
    flat_true_labels = np.array([item for sublist in true_labels for item in sublist])
    f1,acc = evaluate(flat_true_labels, flat_predictions)
    return f1,acc

# %%
def get_diction(key, values):
    train = pd.read_csv('one_hot_train.csv')
    dev = pd.read_csv('one_hot_valid.csv')
    test = pd.read_csv('one_hot_test.csv')
    print(len(train))
    train = train[train[key] == 1] 
    dev = dev[dev[key] == 1]
    print(len(train))
    cols = train.columns
    sentences = train.text_processed.values
    demos = train[cols[4:]].values
    labels = train.label.values
    dev_sentences = dev.text_processed.values
    dev_demos = dev[cols[4:]].values
    dev_labels = dev.label.values
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
    input_ids = []
    dev_input_ids = []
    for sent in sentences:
        encoded_sent = tokenizer.encode(str(sent),add_special_tokens = True,)
        input_ids.append(encoded_sent)

    for sent in dev_sentences:
        encoded_sent = tokenizer.encode(str(sent),add_special_tokens = True,)
        dev_input_ids.append(encoded_sent)
    MAX_LEN = 128*2

    # print('\nPadding/truncating all sentences to %d values...' % MAX_LEN)

    # print('\nPadding token: "{:}", ID: {:}'.format(tokenizer.pad_token, tokenizer.pad_token_id))

    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                            value=0, truncating="post", padding="post")

    dev_input_ids = pad_sequences(dev_input_ids, maxlen=MAX_LEN, dtype="long", 
                            value=0, truncating="post", padding="post")
    # print('\nDone.')
    attention_masks = []
    dev_attention_masks = []

    for sent in input_ids:
        att_mask = [int(token_id > 0) for token_id in sent]
        attention_masks.append(att_mask)

    for sent in dev_input_ids:
        att_mask = [int(token_id > 0) for token_id in sent]
        dev_attention_masks.append(att_mask)
        
    train_inputs = input_ids 
    validation_inputs = dev_input_ids
    train_labels = labels
    validation_labels = dev_labels
    train_demos = demos
    validation_demos = dev_demos
    train_masks =  attention_masks
    validation_masks = dev_attention_masks
    train_inputs = torch.tensor(train_inputs).to(torch.int64)
    validation_inputs = torch.tensor(validation_inputs).to(torch.int64)
    train_labels = torch.tensor(train_labels).to(torch.int64)
    validation_labels = torch.tensor(validation_labels).to(torch.int64)
    train_masks = torch.tensor(train_masks)
    validation_masks = torch.tensor(validation_masks)
    train_demos = torch.tensor(train_demos).to(torch.int64)
    validation_demos = torch.tensor(validation_demos).to(torch.int64)
    batch_size = 32
    train_data = TensorDataset(train_inputs, train_masks, train_demos, train_labels)
    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
    validation_data = TensorDataset(validation_inputs, validation_masks, validation_demos, validation_labels)
    validation_sampler = SequentialSampler(validation_data)
    validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)
    model_bert = BertModel.from_pretrained("bert-base-uncased", # Use the 12-layer BERT model, with an uncased vocab.
        output_attentions = False, # Whether the model returns attentions weights.
        output_hidden_states = False,)
    model = NewModel(model_bert,)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.to(device)
    optimizer = AdamW(model.parameters(),
                    lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                    eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                    )
    epochs = 1
    total_steps = len(train_dataloader) * epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, 
                                                num_warmup_steps = 0, # Default value in run_glue.py
                                                num_training_steps = total_steps)
        
    seed_val = 42

    random.seed(seed_val)
    np.random.seed(seed_val)
    torch.manual_seed(seed_val)
    torch.cuda.manual_seed_all(seed_val)
    loss_values = []
    criterion = nn.CrossEntropyLoss().to(device)
    for epoch_i in range(0, epochs):
        # print("")
        # print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
        # print('Training...')
        t0 = time.time()
        total_loss = 0
        model.train()
        for step, batch in enumerate(train_dataloader):
            if step % 40 == 0 and not step == 0:
                elapsed = format_time(time.time() - t0)
                # print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))
            model.zero_grad()        
            outputs = model(batch)
            b_labels = batch[-1].to(device)
            logits = outputs
            loss = criterion(logits,b_labels)
            total_loss += loss.item()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            scheduler.step()
        avg_train_loss = total_loss / len(train_dataloader)            
        loss_values.append(avg_train_loss)
        # print("")
        # print("  Average training loss: {0:.2f}".format(avg_train_loss))
        # print("  Training epoch took: {:}".format(format_time(time.time() - t0)))
        # print("")
        # print("Running Validation...")

        t0 = time.time()
        model.eval()
        eval_loss, eval_accuracy = 0, 0
        nb_eval_steps, nb_eval_examples = 0, 0
        predictions , true_labels = [], []
        for batch in validation_dataloader:
            batch = tuple(t.to(device) for t in batch)
            with torch.no_grad():        
                outputs = model(batch)
                b_labels = batch[-1].to(device)
            logits = outputs
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()
            predictions.append(logits)
            true_labels.append(label_ids)
            tmp_eval_accuracy = flat_accuracy(logits, label_ids)
            eval_accuracy += tmp_eval_accuracy
            nb_eval_steps += 1
        if nb_eval_steps!=0:
            # print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
            # print("  Validation took: {:}".format(format_time(time.time() - t0)))
            flat_predictions = [item for sublist in predictions for item in sublist]
            flat_predictions = np.argmax(flat_predictions, axis=1).flatten()
            flat_true_labels = [item for sublist in true_labels for item in sublist]
            _ = evaluate(flat_true_labels, flat_predictions)

    # print("")
    print("Training complete!")
    test_df = pd.read_csv('one_hot_test.csv')
    diction = {}
    for i in values:
        print("Stats for ",i)
        stats = test_stats(test_df[test_df[i]==1],tokenizer=tokenizer, model = model, MAX_LEN=MAX_LEN)
        diction[i] = (stats) 
        # print("\n\n\n\n")
    return diction

# %%
countries = ['Botswana', 'Brazil', 'Canada', 'France', 'Germany', 'India', 
             'Israel', 'Italy', 'Mexico', 'NA_Country', 'Spain', 'Turkey', 'UK', 'USA',
             'United Arab Emirates', 'United Kingdom', 'Vietnam']
races = ['African', 'Arabs',
       'Asians', 'Caucasian', 'Hispanic', 'Indian', 'Other']
religions = ['Christian',
       'Hindu', 'Islam', 'Jews', 'Nonreligious', 'Other_Rel']
genders = ['Female', 'Male',
       'NoMentionGender']
targets = ['targetBisexual', 'targetIndigenous', 'targetCaucasian',
       'targetEconomic', 'targetChristian', 'targetHindu', 'targetOther',
       'targetJewish', 'targetMen', 'targetArab', 'targetBuddhism',
       'targetWomen', 'targetHomosexual', 'targetNone', 'targetAfrican',
       'targetIndian', 'targetMinority', 'targetHeterosexual',
       'targetHispanic', 'targetRefugee', 'targetDisability', 'targetIslam',
       'targetNonreligious', 'targetAsian']
ages = ['18--24', '25--29', '30--39', '40--49', '50--65',
       '65++']

# %%
# diction_countries = {}
# for v in countries:
#     print('Doing for ',v)
#     diction_countries[v] = get_diction(v,countries)
#     # print(diction_countries)

diction_races = {}
for v in races:
    print('Doing for ',v)
    diction_races[v] = get_diction(v,races)
    # print(diction_countries)

# %%
races = pd.DataFrame.from_dict(diction_races).T
races.to_pickle("Races.pkl")

# %%
len(train)
# Out:
# 11553

# %%
Overall = get_diction(cols,cols)
# Out:
# 11553
# 11553
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training complete!
# Stats for  Unnamed: 0
# ...
